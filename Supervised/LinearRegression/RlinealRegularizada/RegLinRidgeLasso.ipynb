# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = 'Consumo de Combustible CO2.xlsx'
df = pd.read_excel(data)
df
# Out:
#      MODELYEAR   MAKE              MODEL   VEHICLECLASS  ENGINESIZE  \
# 0         2022  Acura                ILX        Compact         2.4
# 1         2022  Acura         MDX SH-AWD     SUV: Small         3.5
# 2         2022  Acura         RDX SH-AWD     SUV: Small         2.0
# 3         2022  Acura  RDX SH-AWD A-SPEC     SUV: Small         2.0
# 4         2022  Acura         TLX SH-AWD        Compact         2.0
# ..         ...    ...                ...            ...         ...
# 940       2022  Volvo        XC40 T5 AWD     SUV: Small         2.0
# 941       2022  Volvo        XC60 B5 AWD     SUV: Small         2.0
# 942       2022  Volvo        XC60 B6 AWD     SUV: Small         2.0
# 943       2022  Volvo        XC90 T5 AWD  SUV: Standard         2.0
# 944       2022  Volvo        XC90 T6 AWD  SUV: Standard         2.0
#
#      CYLINDERS TRANSMISSION FUELTYPE  FUELCONSUMPTION_CITY  \
# 0            4          AM8        Z                   9.9
# ...

# %%
df.info()   # No existen valores nulos en este dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 945 entries, 0 to 944
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   MODELYEAR                 945 non-null    int64
#  1   MAKE                      945 non-null    object
#  2   MODEL                     945 non-null    object
#  3   VEHICLECLASS              945 non-null    object
#  4   ENGINESIZE                945 non-null    float64
#  5   CYLINDERS                 945 non-null    int64
#  6   TRANSMISSION              945 non-null    object
#  7   FUELTYPE                  945 non-null    object
#  8   FUELCONSUMPTION_CITY      945 non-null    float64
#  9   FUELCONSUMPTION_HWY       945 non-null    float64
#  10  FUELCONSUMPTION_COMB      945 non-null    float64
#  11  FUELCONSUMPTION_COMB_MPG  945 non-null    int64
#  12  CO2EMISSIONS              945 non-null    int64
# dtypes: float64(4), int64(4), object(5)
# ...

# %%
# Remover caracteristicas categoricas
df.drop(['MODELYEAR', 'MAKE', 'MODEL', 'VEHICLECLASS', 'ENGINESIZE', 'CYLINDERS', 'TRANSMISSION', 'FUELTYPE'], axis = 1, inplace = True)
df
# Out:
#      FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  FUELCONSUMPTION_COMB  \
# 0                     9.9                  7.0                   8.6
# 1                    12.6                  9.4                  11.2
# 2                    11.0                  8.6                   9.9
# 3                    11.3                  9.1                  10.3
# 4                    11.2                  8.0                   9.8
# ..                    ...                  ...                   ...
# 940                  10.7                  7.7                   9.4
# 941                  10.5                  8.1                   9.4
# 942                  11.0                  8.7                   9.9
# 943                  11.5                  8.4                  10.1
# 944                  12.4                  8.9                  10.8
#
#      FUELCONSUMPTION_COMB_MPG  CO2EMISSIONS
# 0                          33           200
# 1                          25           263
# ...

# %%
x = df.drop('CO2EMISSIONS', axis = 1)
y = df['CO2EMISSIONS']

# %%
x
# Out:
#      FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  FUELCONSUMPTION_COMB  \
# 0                     9.9                  7.0                   8.6
# 1                    12.6                  9.4                  11.2
# 2                    11.0                  8.6                   9.9
# 3                    11.3                  9.1                  10.3
# 4                    11.2                  8.0                   9.8
# ..                    ...                  ...                   ...
# 940                  10.7                  7.7                   9.4
# 941                  10.5                  8.1                   9.4
# 942                  11.0                  8.7                   9.9
# 943                  11.5                  8.4                  10.1
# 944                  12.4                  8.9                  10.8
#
#      FUELCONSUMPTION_COMB_MPG
# 0                          33
# 1                          25
# 2                          29
# ...

# %%
y
# Out:
# 0      200
# 1      263
# 2      232
# 3      242
# 4      230
#       ...
# 940    219
# 941    219
# 942    232
# 943    236
# 944    252
# Name: CO2EMISSIONS, Length: 945, dtype: int64

# %%
# Division en los conjuntos de prueba y de entrenamiento
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.30, random_state = 1)

# %% [markdown]
# # Regression Lineal multiple

# %%
# Construccion de un modelo de regresion lineal multiple
from sklearn.linear_model import LinearRegression
linreg = LinearRegression()
linreg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
# Impresion de los coeficientes de regresión 
print('Intercepto:', linreg.intercept_)
print('Coeficientes:', linreg.coef_)
# Out:
# Intercepto: 95.93361319267373
# Coeficientes: [10.85607131  5.91025898  0.71589393 -1.33087138]

# %%
# Predicciones
y_pred = linreg.predict(x_test)

# Calculo de indicadores de la bondad de ajuste
from sklearn.metrics import r2_score
from sklearn import metrics
print('Valor de R cuadrada:', r2_score(y_test, y_pred))
print('Error absoluto medio:', metrics.mean_absolute_error(y_test, y_pred))
print('Error cuadratico medio:', metrics.mean_squared_error(y_test, y_pred))
print('Raiz del error cuadratico medio:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Valor de R cuadrada: 0.9809388418270502
# Error absoluto medio: 5.6945196646270695
# Error cuadratico medio: 72.94435631403718
# Raiz del error cuadratico medio: 8.540746824138811

# %%
print(y_test)
# Out:
# 786    334
# 94     322
# 265    359
# 741    171
# 861    192
#       ...
# 544    182
# 57     262
# 553    238
# 826    245
# 862    235
# Name: CO2EMISSIONS, Length: 284, dtype: int64

# %%
print("Primer valor de la base de prueba:", y_test[786], "Valor Pronosticado:", y_pred[0])
# Out:
# Primer valor de la base de prueba: 334 Valor Pronosticado: 323.9684701962643

# %%
predition = 95.93361319267373 + x_test['FUELCONSUMPTION_CITY'][786]*10.85607131 + x_test['FUELCONSUMPTION_HWY'][786]*5.91025898 + x_test['FUELCONSUMPTION_COMB'][786]*0.71589393 + x_test['FUELCONSUMPTION_COMB_MPG'][786]*-1.33087138
predition
# Out:
# 323.96847027367374

# %% [markdown]
# # Regression Ridge con

# %%
from sklearn.linear_model import RidgeCV
# Definir un rango de prueba para alpha
alpha_range = 10.**np.arange(-3,3)

# normalizacion de los datos por que el parametro normalize ya no esta disponible en esta version
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

ridgeregcv = RidgeCV(alphas = alpha_range, scoring = 'neg_mean_squared_error')
ridgeregcv.fit(x_train_scaled, y_train)
ridgeregcv.alpha_
# Out:
# 1.0

# %%
# examinacion de los coeficientes de la regresion RidgeCV
print('Intercepto:', ridgeregcv.intercept_)
print('Coeficientes:', ridgeregcv.coef_)
# Out:
# Intercepto: 261.5658093797277
# Coeficientes: [ 27.12394459   8.0029375   19.06980224 -10.35272381]

# %%
# Prediccion mediante el mejor valor de alpha
y_pred = ridgeregcv.predict(x_test_scaled)

# Impresion de indicadores de bondad de ajuste
print('Valor de R cuadrada:', r2_score(y_test, y_pred))
print('Error absoluto medio:', metrics.mean_absolute_error(y_test, y_pred))
print('Error cuadratico medio:', metrics.mean_squared_error(y_test, y_pred))
print('Raiz del error cuadratico medio:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Valor de R cuadrada: 0.9809560833878679
# Error absoluto medio: 5.695954292829709
# Error cuadratico medio: 72.87837529943747
# Raiz del error cuadratico medio: 8.536883230982925

# %%
print(y_test)
# Out:
# 786    334
# 94     322
# 265    359
# 741    171
# 861    192
#       ...
# 544    182
# 57     262
# 553    238
# 826    245
# 862    235
# Name: CO2EMISSIONS, Length: 284, dtype: int64

# %%
print("Primer valor de la base de prueba:", y_test[786], "Valor Pronosticado:", y_pred[0])
# Out:
# Primer valor de la base de prueba: 334 Valor Pronosticado: 324.0474574749009

# %%
predition = 261.5658093797277 + x_test['FUELCONSUMPTION_CITY'][786]*27.12394459 + x_test['FUELCONSUMPTION_HWY'][786]*8.0029375 + x_test['FUELCONSUMPTION_COMB'][786]*19.06980224 + x_test['FUELCONSUMPTION_COMB_MPG'][786]*-10.35272381
predition
# Out:
# 851.9803470657278

# %% [markdown]
# # Regression Lasso con Alpha optimo

# %%
# Seleccion del valor optimo de Alpha para la regression de lasso
from sklearn.linear_model import LassoCV
lassoregcv = LassoCV(n_alphas = 100, random_state = 1)
lassoregcv.fit(x_train_scaled, y_train)
print('Alpha optimo:', lassoregcv.alpha_)
# Out:
# Alpha optimo: 0.4770455394673273

# %%
print('Intercepto:', lassoregcv.intercept_)
print('Coeficientes:', lassoregcv.coef_)
# Out:
# Intercepto: 261.5658093797277
# Coeficientes: [ 33.06696457  10.85722301  10.2782818  -10.01861753]

# %%
# Prediccion mediante regresion de lasso con un Alpha optimo
y_pred = lassoregcv.predict(x_test_scaled)

# Impresion de indicadores de bondad de ajuste
print('Valor de R cuadrada:', r2_score(y_test, y_pred))
print('Error absoluto medio:', metrics.mean_absolute_error(y_test, y_pred))
print('Error cuadratico medio:', metrics.mean_squared_error(y_test, y_pred))
print('Raiz del error cuadratico medio:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Valor de R cuadrada: 0.9800881187402285
# Error absoluto medio: 5.941895300445985
# Error cuadratico medio: 76.19995324086823
# Raiz del error cuadratico medio: 8.729258458819295

# %%
print(y_test)
# Out:
# 786    334
# 94     322
# 265    359
# 741    171
# 861    192
#       ...
# 544    182
# 57     262
# 553    238
# 826    245
# 862    235
# Name: CO2EMISSIONS, Length: 284, dtype: int64

# %%
print("Primer valor de la base de prueba:", y_test[786], "Valor Pronosticado:", y_pred[0])
# Out:
# Primer valor de la base de prueba: 334 Valor Pronosticado: 323.448776808842

# %%
predition = 261.5658093797277 + x_test['FUELCONSUMPTION_CITY'][786]*33.06696457 + x_test['FUELCONSUMPTION_HWY'][786]*10.85722301 + x_test['FUELCONSUMPTION_COMB'][786]*10.2782818 + x_test['FUELCONSUMPTION_COMB_MPG'][786]*-10.01861753
predition
# Out:
# 861.9042680387275
